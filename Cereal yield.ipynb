# %% [markdown]
# ### Task 1

# %% [markdown]
# #### Visualisation and Analytics of Geospatial Data

# %%
#importing the necessary python libraries

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#reading the cereal dataset into cereal dataframe

cereal = pd.read_csv('API_AG.YLD.CREL.KG_DS2_en_csv_v2_5734359.csv', skiprows= 4)
cereal.head()
# Out:
#                   Country Name Country Code                 Indicator Name  \
# 0                        Aruba          ABW  Cereal yield (kg per hectare)
# 1  Africa Eastern and Southern          AFE  Cereal yield (kg per hectare)
# 2                  Afghanistan          AFG  Cereal yield (kg per hectare)
# 3   Africa Western and Central          AFW  Cereal yield (kg per hectare)
# 4                       Angola          AGO  Cereal yield (kg per hectare)
#
#    Indicator Code  1960         1961         1962        1963         1964  \
# 0  AG.YLD.CREL.KG   NaN          NaN          NaN         NaN          NaN
# 1  AG.YLD.CREL.KG   NaN   924.111737   931.506715  934.015106   879.750864
# 2  AG.YLD.CREL.KG   NaN  1115.100000  1079.000000  985.800000  1082.800000
# 3  AG.YLD.CREL.KG   NaN   675.354816   702.244456  698.032526   691.134187
# 4  AG.YLD.CREL.KG   NaN   828.000000   830.300000  798.400000   875.800000
#
#           1965  ...         2014         2015         2016         2017  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1   869.584522  ...  1636.009730  1616.362162  1490.807738  1764.116707
# 2  1098.900000  ...  2017.500000  2132.200000  1980.400000  2022.500000
# 3   658.343442  ...  1226.442299  1268.162021  1314.142638  1287.720920
# 4   932.000000  ...   888.200000   982.400000   865.400000   806.200000
#
#           2018         2019         2020         2021  2022  Unnamed: 67
# 0          NaN          NaN          NaN          NaN   NaN          NaN
# 1  1728.295922  1717.894885  1838.762607  1840.899744   NaN          NaN
# 2  2162.000000  2113.400000  1979.900000  2154.700000   NaN          NaN
# 3  1334.535720  1343.462790  1381.643141  1341.959411   NaN          NaN
# 4   941.400000   958.800000   992.500000  1000.300000   NaN          NaN
#
# [5 rows x 68 columns]

# %% [markdown]
# ##### Data cleaning

# %%
# getting the columns from 1960 to 2022 in a list

columns = cereal.columns[4:-1]

# %%
columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# fill the nan with the previous column value for columns 1960 to 2022. This is done to reduce large variations in the yield data

for i in columns:
    cereal[i].fillna(method='ffill', inplace=True)

cereal.head()
# Out:
# <ipython-input-6-63a5449f8b53>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cereal[i].fillna(method='ffill', inplace=True)
#                   Country Name Country Code                 Indicator Name  \
# 0                        Aruba          ABW  Cereal yield (kg per hectare)
# 1  Africa Eastern and Southern          AFE  Cereal yield (kg per hectare)
# 2                  Afghanistan          AFG  Cereal yield (kg per hectare)
# 3   Africa Western and Central          AFW  Cereal yield (kg per hectare)
# 4                       Angola          AGO  Cereal yield (kg per hectare)
#
#    Indicator Code  1960         1961         1962        1963         1964  \
# 0  AG.YLD.CREL.KG   NaN          NaN          NaN         NaN          NaN
# 1  AG.YLD.CREL.KG   NaN   924.111737   931.506715  934.015106   879.750864
# 2  AG.YLD.CREL.KG   NaN  1115.100000  1079.000000  985.800000  1082.800000
# 3  AG.YLD.CREL.KG   NaN   675.354816   702.244456  698.032526   691.134187
# 4  AG.YLD.CREL.KG   NaN   828.000000   830.300000  798.400000   875.800000
#
#           1965  ...         2014         2015         2016         2017  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1   869.584522  ...  1636.009730  1616.362162  1490.807738  1764.116707
# 2  1098.900000  ...  2017.500000  2132.200000  1980.400000  2022.500000
# 3   658.343442  ...  1226.442299  1268.162021  1314.142638  1287.720920
# 4   932.000000  ...   888.200000   982.400000   865.400000   806.200000
#
#           2018         2019         2020         2021  2022  Unnamed: 67
# 0          NaN          NaN          NaN          NaN   NaN          NaN
# 1  1728.295922  1717.894885  1838.762607  1840.899744   NaN          NaN
# 2  2162.000000  2113.400000  1979.900000  2154.700000   NaN          NaN
# 3  1334.535720  1343.462790  1381.643141  1341.959411   NaN          NaN
# 4   941.400000   958.800000   992.500000  1000.300000   NaN          NaN
#
# [5 rows x 68 columns]

# %%
# checking null values

cereal[columns].isna().sum()
# Out:
# 1960    266
# 1961      1
# 1962      1
# 1963      1
# 1964      1
#        ...
# 2018      1
# 2019      1
# 2020      1
# 2021      1
# 2022    266
# Length: 63, dtype: int64

# %%
# finding the columns with full nan value (total rows in cereal is 266)

a=cereal[columns].isna().sum()
print(a[a==266].index)
# Out:
# Index(['1960', '2022'], dtype='object')

# %%
# drop columns not useful

cereal.drop(['1960','2022','Indicator Name', 'Indicator Code','Unnamed: 67'],axis=1,inplace=True)

# %%
cereal.columns
# Out:
# Index(['Country Name', 'Country Code', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021'],
#       dtype='object')

# %%
# remove 1960 and 2022 from the columns list

columns= columns[1:-1]

# %%
# finding the country with no cereal yield value for all years

cereal[cereal.isna().any(axis=1)]['Country Name']
# Out:
# 0    Aruba
# Name: Country Name, dtype: object

# %%
#removing the country with no cereal yield value

cereal =  cereal[cereal['Country Name'] != 'Aruba']

# %%
# checking for null values in the dataframe

cereal[columns].isna().sum()
# Out:
# 1961    0
# 1962    0
# 1963    0
# 1964    0
# 1965    0
#        ..
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# Length: 61, dtype: int64

# %%
#importing the geopandas dataset 'naturalearth_lowres' for geometry

loc = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# <ipython-input-15-a8efad925113>:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   loc = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
loc.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
# rename Country Code column to iso_a3 to merge cereal and loc dataframe to create a geopandas dataframe

cereal.rename(columns={'Country Code':'iso_a3'},inplace=True)

# %%
# drop columns not used in loc

loc.drop(['pop_est', 'continent', 'name','gdp_md_est'], axis=1, inplace=True)

# %%
# merge cereal and loc dataframe

cereal_geo = pd.merge(loc,cereal, on='iso_a3')

# %%
# Create choropleth map for 2019

fig = px.choropleth(cereal_geo,
                          geojson=cereal_geo['Country Name'],
                          locations = cereal_geo['iso_a3'],
                          color='2019',
                          hover_name='Country Name',
                          custom_data=[cereal_geo['Country Name'],cereal_geo['2019']],
                          title='Cereal Yield (kg/ha) - 2019',
                          color_continuous_scale='sunset')

fig.update_geos(fitbounds="locations", visible=False)

fig.update_traces(hovertemplate='<b>%{customdata[0]}</b><br>Cereal yield: %{customdata[1]:.2f}<extra></extra>')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="22b50e63-b6ba-4181-a027-e3c21ea551dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22b50e63-b6ba-4181-a027-e3c21ea551dc")) {                    Plotly.newPlot(                        "22b50e63-b6ba-4181-a027-e3c21ea551dc",                        [{"coloraxis":"coloraxis","customdata":[["Fiji",3353.4],["Tanzania",1883.3],["Canada",4010.8],["United States",8006.1],["Kazakhstan",1154.5],["Uzbekistan",4533.6],["Papua New Guinea",4654.5],["Indonesia",5198.2],["Argentina",5474.8],["Chile",7157.2],["Congo, Dem. Rep.",838.0],["Somalia",522.2],["Kenya",1607.9],["Sudan",552.9],["Chad",886.3],["Haiti",1599.3],["Dominican Republic",4652.5],["Russian Federation",2713.8],["Bahamas, The",8341.7],["Norway",4709.8],["Greenland",998.5],["Timor-Leste",2354.2],["South Africa",4101.4],["Lesotho",695.5],["Mexico",3992.4],["Uruguay",5329.7],["Brazil",5321.5],["Bolivia",2030.1],["Peru",4370.1],["Colombia",4847.4],["Panama",3301.2],["Costa Rica",4052.4],["Nicaragua",2248.8],["Honduras",1871.1],["El Salvador",2777.0],["Guatemala",2164.5],["Belize",2946.5],["Venezuela, RB",3132.6],["Guyana",3798.0],["Suriname",4555.3],["France",7491.9],["Ecuador",4326.1],["Puerto Rico",2862.1],["Jamaica",1125.8],["Cuba",2830.9],["Zimbabwe",748.0],["Botswana",676.3],["Namibia",731.5],["Senegal",1601.3],["Mali",1767.7],["Mauritania",1345.5],["Benin",1238.3],["Niger",501.5],["Nigeria",1651.7],["Cameroon",1664.7],["Togo",1143.0],["Ghana",2207.0],["Cote d'Ivoire",2274.5],["Guinea",1257.9],["Guinea-Bissau",1278.7],["Liberia",1128.2],["Sierra Leone",1520.6],["Burkina Faso",1156.1],["Central African Republic",859.3],["Congo, Rep.",875.7],["Gabon",1589.1],["Equatorial Guinea",1278.7],["Zambia",2400.4],["Malawi",1874.0],["Mozambique",835.4],["Eswatini",1264.6],["Angola",958.8],["Burundi",1445.7],["Israel",3625.1],["Lebanon",3117.2],["Madagascar",2389.0],["West Bank and Gaza",2234.7],["Gambia, The",443.8],["Tunisia",1948.5],["Algeria",1767.4],["Jordan",1641.8],["United Arab Emirates",23842.3],["Qatar",6594.9],["Kuwait",17625.4],["Iraq",2586.4],["Oman",13291.0],["Vanuatu",618.2],["Cambodia",3431.4],["Thailand",3021.1],["Lao PDR",4317.6],["Myanmar",3660.4],["Vietnam",5715.8],["Korea, Dem. People's Rep.",4385.7],["Korea, Rep.",6538.6],["Mongolia",1271.9],["India",3416.1],["Bangladesh",4811.4],["Bhutan",3080.7],["Nepal",3093.6],["Pakistan",3160.6],["Afghanistan",2113.4],["Tajikistan",3636.7],["Kyrgyz Republic",3233.9],["Turkmenistan",2214.1],["Iran, Islamic Rep.",1975.4],["Syrian Arab Republic",2203.9],["Armenia",1690.6],["Sweden",6292.1],["Belarus",3095.6],["Ukraine",4975.8],["Poland",3605.3],["Austria",6954.3],["Hungary",6365.8],["Moldova",3859.0],["Romania",5457.5],["Lithuania",3858.9],["Latvia",4310.1],["Estonia",4458.6],["Germany",6952.0],["Bulgaria",5774.7],["Greece",4043.5],["Turkiye",3200.8],["Albania",5038.2],["Croatia",7157.3],["Switzerland",6580.8],["Luxembourg",5972.6],["Belgium",8988.5],["Netherlands",8654.2],["Portugal",5176.5],["Spain",3445.5],["Ireland",8505.2],["New Caledonia",7031.1],["Solomon Islands",1897.7],["New Zealand",8205.0],["Australia",1769.0],["Sri Lanka",4737.4],["China",6265.9],["Italy",5336.2],["Denmark",6928.9],["United Kingdom",7946.0],["Iceland",3590.9],["Azerbaijan",3239.0],["Georgia",2536.9],["Philippines",3737.9],["Malaysia",3552.2],["Brunei Darussalam",1941.0],["Slovenia",6503.1],["Finland",4257.5],["Slovak Republic",5336.0],["Czechia",5653.2],["Eritrea",639.8],["Japan",6546.7],["Paraguay",4601.1],["Yemen, Rep.",864.9],["Saudi Arabia",5295.4],["Cyprus",2656.3],["Morocco",1453.8],["Egypt, Arab Rep.",6045.3],["Libya",676.3],["Ethiopia",2831.8],["Djibouti",1999.5],["Uganda",2524.5],["Rwanda",1446.4],["Bosnia and Herzegovina",5354.7],["Nor ...

# %%
# Create choropleth map for 2020
fig = px.choropleth(cereal_geo,
                          geojson=cereal_geo['Country Name'],
                          locations = cereal_geo['iso_a3'],
                          color='2020',
                          hover_name='Country Name',
                          custom_data=[cereal_geo['Country Name'],cereal_geo['2020']],
                          title='Cereal Yield (kg/ha) - 2020',
                          color_continuous_scale='sunset')

fig.update_geos(fitbounds="locations", visible=False)

fig.update_traces(hovertemplate='<b>%{customdata[0]}</b><br>Cereal yield: %{customdata[1]:.2f}<extra></extra>')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="297ac5d4-2383-412c-8274-faae2dbd99bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("297ac5d4-2383-412c-8274-faae2dbd99bb")) {                    Plotly.newPlot(                        "297ac5d4-2383-412c-8274-faae2dbd99bb",                        [{"coloraxis":"coloraxis","customdata":[["Fiji",3665.7],["Tanzania",1698.4],["Canada",4095.4],["United States",8145.3],["Kazakhstan",1288.6],["Uzbekistan",4481.1],["Papua New Guinea",4755.9],["Indonesia",5293.3],["Argentina",5213.1],["Chile",6245.8],["Congo, Dem. Rep.",879.9],["Somalia",502.5],["Kenya",1842.6],["Sudan",489.6],["Chad",867.1],["Haiti",1301.1],["Dominican Republic",4653.7],["Russian Federation",2905.4],["Bahamas, The",8408.6],["Norway",4683.8],["Greenland",998.0],["Timor-Leste",2658.5],["South Africa",5120.6],["Lesotho",433.3],["Mexico",3806.5],["Uruguay",4964.1],["Brazil",5255.7],["Bolivia",2024.0],["Peru",4557.2],["Colombia",5069.2],["Panama",3377.4],["Costa Rica",4030.4],["Nicaragua",2223.7],["Honduras",1893.3],["El Salvador",2732.0],["Guatemala",2201.2],["Belize",3526.3],["Venezuela, RB",4034.8],["Guyana",3666.2],["Suriname",4319.1],["France",6384.2],["Ecuador",3914.7],["Puerto Rico",2869.1],["Jamaica",1114.3],["Cuba",2572.3],["Zimbabwe",1148.6],["Botswana",1034.7],["Namibia",429.5],["Senegal",1821.6],["Mali",1686.0],["Mauritania",1321.8],["Benin",1432.8],["Niger",560.2],["Nigeria",1666.9],["Cameroon",1665.8],["Togo",1160.0],["Ghana",2405.6],["Cote d'Ivoire",2231.7],["Guinea",1323.7],["Guinea-Bissau",1334.0],["Liberia",1162.5],["Sierra Leone",1633.2],["Burkina Faso",1261.7],["Central African Republic",859.0],["Congo, Rep.",883.7],["Gabon",1588.6],["Equatorial Guinea",1334.0],["Zambia",2481.6],["Malawi",2004.4],["Mozambique",672.1],["Eswatini",1287.0],["Angola",992.5],["Burundi",1261.7],["Israel",3835.1],["Lebanon",2371.5],["Madagascar",2469.1],["West Bank and Gaza",2244.6],["Gambia, The",501.9],["Tunisia",1325.8],["Algeria",1520.4],["Jordan",2146.1],["United Arab Emirates",25980.3],["Qatar",7124.6],["Kuwait",13393.1],["Iraq",2582.3],["Oman",18835.1],["Vanuatu",609.7],["Cambodia",3481.5],["Thailand",3013.7],["Lao PDR",4014.3],["Myanmar",3651.7],["Vietnam",5797.3],["Korea, Dem. People's Rep.",3495.7],["Korea, Rep.",6212.0],["Mongolia",1218.6],["India",3407.0],["Bangladesh",4902.1],["Bhutan",3439.5],["Nepal",3196.3],["Pakistan",3353.5],["Afghanistan",1979.9],["Tajikistan",3484.7],["Kyrgyz Republic",3260.4],["Turkmenistan",2191.4],["Iran, Islamic Rep.",1653.0],["Syrian Arab Republic",1832.3],["Armenia",2055.8],["Sweden",5994.4],["Belarus",3539.9],["Ukraine",4293.4],["Poland",4691.7],["Austria",7386.4],["Hungary",6659.1],["Moldova",1893.6],["Romania",3398.6],["Lithuania",4734.2],["Latvia",4662.8],["Estonia",4411.5],["Germany",7133.3],["Bulgaria",4373.4],["Greece",4197.1],["Turkiye",3341.5],["Albania",5209.2],["Croatia",6992.4],["Switzerland",6978.0],["Luxembourg",5736.8],["Belgium",8430.6],["Netherlands",7919.9],["Portugal",4881.3],["Spain",4501.5],["Ireland",7124.8],["New Caledonia",8689.9],["Solomon Islands",1889.4],["New Zealand",9039.3],["Australia",1650.7],["Sri Lanka",4746.8],["China",6314.2],["Italy",5626.5],["Denmark",6926.3],["United Kingdom",6241.0],["Iceland",4858.0],["Azerbaijan",3227.3],["Georgia",2646.5],["Philippines",3769.4],["Malaysia",3706.4],["Brunei Darussalam",2944.2],["Slovenia",7385.5],["Finland",3589.3],["Slovak Republic",6129.8],["Czechia",6042.7],["Eritrea",640.0],["Japan",6472.9],["Paraguay",4706.5],["Yemen, Rep.",861.1],["Saudi Arabia",4856.9],["Cyprus",2368.5],["Morocco",747.4],["Egypt, Arab Rep.",7166.5],["Libya",672.9],["Ethiopia",2861.3],["Djibouti",2000.0],["Uganda",2587.0],["Rwanda",1459.2],["Bosnia and Herzegovina",6050.7],["No ...

# %% [markdown]
# According to data on grain yields for 2019 and 2020, Oman and the United Arab Emirates are major producers of cereals. Their yields of cereals have changed, meanwhile, with Oman reporting an increase of 3000 kg/ha and the United Arab Emirates suffering a decrease of about 2000 kg/ha. This change is a reflection of how dynamic agricultural output is and is subject to the effect of a number of variables, including climate, farming methods, and policy.
#
# The data also reveals geographical differences in cereal yield, with Greenland and the African continent reporting the lowest cereal yields. Geospatial analysts may use these insights to better understand how cereal production patterns are changing and the causes behind these changes. This information can help them make decisions about trade, agricultural development, and food security.

# %% [markdown]
# ### Task 1.2

# %%
#reading the population dataset into pop dataframe

pop = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_4485025.csv', skiprows=4)
pop.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2013         2014         2015         2016  \
# 0      57357.0  ...     103165.0     103776.0     104339.0     104865.0
# 1  148769974.0  ...  562601578.0  578075373.0  593871847.0  609978946.0
# 2    9956318.0  ...   32269592.0   33370804.0   34413603.0   35383028.0
# 3  107289875.0  ...  380437896.0  390882979.0  401586651.0  412551299.0
# 4    5770573.0  ...   26015786.0   26941773.0   27884380.0   28842482.0
#
#           2017         2018         2019         2020         2021  \
# 0     105361.0     105846.0     106310.0     106766.0     107195.0
# 1  626392880.0  643090131.0  660046272.0  677243299.0  694665117.0
# 2   36296111.0   37171922.0   38041757.0   38928341.0   39835428.0
# 3  423769930.0  435229381.0  446911598.0  458803476.0  470898870.0
# 4   29816769.0   30809787.0   31825299.0   32866268.0   33933611.0
#
#    Unnamed: 66
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# #### Data Cleaning

# %%
# getting the columns from 1960 to 2022 in a list and checking for null values

col = pop.columns[4:-1]
pop[col].isna().sum()
# Out:
# 1960    2
# 1961    2
# 1962    2
# 1963    2
# 1964    2
#        ..
# 2017    2
# 2018    2
# 2019    2
# 2020    2
# 2021    2
# Length: 62, dtype: int64

# %%
# fill the nan with the previous column value for columns 1960 to 2021. This is done to reduce large variations in the population data

for i in col:
    pop[i].fillna(method='ffill', inplace=True)

pop.head()
# Out:
# <ipython-input-26-f47923a60cdf>:4: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2013         2014         2015         2016  \
# 0      57357.0  ...     103165.0     103776.0     104339.0     104865.0
# 1  148769974.0  ...  562601578.0  578075373.0  593871847.0  609978946.0
# 2    9956318.0  ...   32269592.0   33370804.0   34413603.0   35383028.0
# 3  107289875.0  ...  380437896.0  390882979.0  401586651.0  412551299.0
# 4    5770573.0  ...   26015786.0   26941773.0   27884380.0   28842482.0
#
#           2017         2018         2019         2020         2021  \
# 0     105361.0     105846.0     106310.0     106766.0     107195.0
# 1  626392880.0  643090131.0  660046272.0  677243299.0  694665117.0
# 2   36296111.0   37171922.0   38041757.0   38928341.0   39835428.0
# 3  423769930.0  435229381.0  446911598.0  458803476.0  470898870.0
# 4   29816769.0   30809787.0   31825299.0   32866268.0   33933611.0
#
#    Unnamed: 66
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 67 columns]

# %%
# checking for null values

pop[col].isna().sum()
# Out:
# 1960    0
# 1961    0
# 1962    0
# 1963    0
# 1964    0
#        ..
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# Length: 62, dtype: int64

# %%
# remove columns that are not useful

pop.drop(['Indicator Name', 'Indicator Code','Unnamed: 66'],axis=1,inplace=True)

# %%
# rename Country Code column to iso_a3 for using the pop dataset with cereal dataset for analysis

pop.rename(columns={'Country Code':'iso_a3'},inplace=True)

# %%
# change the Country name in pop to that in the cereal using iso_a3, this is done to remove misinterpretations during analysis

iso_a3_to_country = dict(zip(cereal['iso_a3'], cereal['Country Name']))
pop['Country Name'] = pop['iso_a3'].map(iso_a3_to_country).combine_first(pop['Country Name'])

# %%
# changing the crs to EPSG 3857 for plotting maps

cereal_geo = cereal_geo.to_crs('EPSG: 3857')

# %% [markdown]
# ### Task 1.2.1:
#
# For the year 2021, generate choropleth maps of cereal yield for only the countries having a population less than or equal to 67326569.

# %%
# identifying the countries in cereal with popluation <= 67326569 in 2021 using iso_a3

a = cereal_geo[cereal_geo['iso_a3'].isin(pop.loc[pop['2021']<= 67326569,'iso_a3'])]

# %%
# Create choropleth map to plot the identified countries in dataframe a

fig = px.choropleth(a,
                    geojson=a['Country Name'],
                    locations=a['iso_a3'],
                    color='2021',
                    hover_name='Country Name',
                    custom_data=[a['Country Name'],a['2021']],
                    title='Cereal Yield in 2021 for Countries with Population <= 60000000',
                    color_continuous_scale='ylorbr',
                    projection= 'natural earth')

fig.update_traces(hovertemplate='<b>%{customdata[0]}</b><br>Cereal yield: %{customdata[1]:.2f}<extra></extra>')

fig.update_geos(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="white", visible=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="42746b22-7306-41b6-b966-a5fbf088bd9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42746b22-7306-41b6-b966-a5fbf088bd9e")) {                    Plotly.newPlot(                        "42746b22-7306-41b6-b966-a5fbf088bd9e",                        [{"coloraxis":"coloraxis","customdata":[["Fiji",3887.3],["Tanzania",1651.1],["Canada",3078.3],["Kazakhstan",1049.0],["Uzbekistan",4735.9],["Papua New Guinea",4725.3],["Argentina",5193.2],["Chile",6491.2],["Somalia",502.6],["Kenya",1487.6],["Sudan",566.8],["Chad",814.3],["Haiti",1153.8],["Dominican Republic",4784.8],["Bahamas, The",8419.2],["Norway",4180.4],["Greenland",997.5],["Timor-Leste",1201.9],["South Africa",5124.7],["Lesotho",710.8],["Uruguay",5499.0],["Bolivia",2502.1],["Peru",4686.5],["Colombia",5160.1],["Panama",3518.5],["Costa Rica",4310.0],["Nicaragua",2403.2],["Honduras",1900.2],["El Salvador",2735.8],["Guatemala",2218.0],["Belize",4289.5],["Venezuela, RB",3505.0],["Guyana",3683.5],["Suriname",4638.3],["Ecuador",4418.8],["Puerto Rico",2883.4],["Jamaica",1118.0],["Cuba",2403.9],["Zimbabwe",1545.2],["Botswana",1003.7],["Namibia",517.3],["Senegal",1864.0],["Mali",1441.2],["Mauritania",2046.1],["Benin",1408.6],["Niger",349.6],["Cameroon",1669.4],["Togo",1145.9],["Ghana",2416.2],["Cote d'Ivoire",2294.0],["Guinea",1344.9],["Guinea-Bissau",1343.9],["Liberia",1065.0],["Sierra Leone",2000.4],["Burkina Faso",1252.4],["Central African Republic",799.6],["Congo, Rep.",883.5],["Gabon",1588.7],["Equatorial Guinea",1343.9],["Zambia",2525.0],["Malawi",2441.0],["Mozambique",1008.5],["Eswatini",1432.4],["Angola",1000.3],["Burundi",1481.5],["Israel",3508.8],["Lebanon",2178.2],["Madagascar",2675.3],["West Bank and Gaza",2271.4],["Gambia, The",490.7],["Tunisia",1453.8],["Algeria",1433.7],["Jordan",2290.1],["United Arab Emirates",26226.2],["Qatar",8431.1],["Kuwait",11216.7],["Iraq",2729.6],["Oman",16461.4],["Vanuatu",609.5],["Cambodia",3606.0],["Lao PDR",4392.2],["Myanmar",3612.2],["Korea, Dem. People's Rep.",3387.9],["Korea, Rep.",6809.4],["Mongolia",1420.0],["Bhutan",3342.4],["Nepal",3208.4],["Afghanistan",2154.7],["Tajikistan",3609.6],["Kyrgyz Republic",2334.9],["Turkmenistan",2033.6],["Syrian Arab Republic",820.4],["Armenia",2243.4],["Sweden",5064.7],["Belarus",3143.2],["Ukraine",5453.1],["Poland",4562.5],["Austria",7112.4],["Hungary",5920.0],["Moldova",4947.7],["Romania",5187.8],["Lithuania",3937.2],["Latvia",3900.2],["Estonia",3502.4],["Bulgaria",5949.6],["Greece",4272.7],["Albania",5144.7],["Croatia",7012.9],["Switzerland",5526.7],["Luxembourg",5593.3],["Belgium",7906.2],["Netherlands",7872.3],["Portugal",5379.7],["Spain",4227.4],["Ireland",8606.5],["New Caledonia",7810.9],["Solomon Islands",1899.3],["New Zealand",8728.4],["Australia",2548.0],["Sri Lanka",4557.2],["Italy",5562.8],["Denmark",6355.0],["United Kingdom",6966.8],["Iceland",3120.8],["Azerbaijan",3297.4],["Georgia",2749.3],["Malaysia",3801.7],["Brunei Darussalam",2885.2],["Slovenia",6864.8],["Finland",2777.3],["Slovak Republic",5976.8],["Czechia",6113.0],["Paraguay",3823.1],["Yemen, Rep.",791.8],["Saudi Arabia",5021.7],["Cyprus",1990.2],["Morocco",2328.2],["Libya",673.4],["Djibouti",2000.4],["Uganda",2456.1],["Rwanda",1504.7],["Bosnia and Herzegovina",4422.1],["North Macedonia",3537.8],["Serbia",5768.6],["Montenegro",3330.7],["Trinidad and Tobago",1588.1],["South Sudan",844.6]],"geo":"geo","geojson":["Fiji","Tanzania","Canada","Kazakhstan","Uzbekistan","Papua New Guinea","Argentina","Chile","Somalia","Kenya","Sudan","Chad","Haiti","Dominican Republic","Bahamas, The","Norway","Greenland","Timor-Leste","South Africa","Lesotho","Uruguay","Bolivia","Peru","Colombia","Panama","Costa Rica","Nicaragua","Honduras","El Salvado ...

# %% [markdown]
# For countries having a population less than or equal to 67326569 in 2021, the plot illustrates that United Arab Emirates (26226.2 kg/ha), Oman (16461.4 kg/ha) have exceptionally high cereal yields, suggesting advanced agricultural practices, the presence of favorable climate conditions for certain crops.
#
# Niger (349.6 kg/ha): Niger has the lowest cereal yield, likely due to challenges such as arid climate conditions, limited access to modern farming techniques, and socio-economic factors affecting agricultural productivity.
#
# The high cereal yield in the UAE and Oman is a result of a combination of strategic investments, favorable environmental conditions, technological advancements, and government policies that prioritize and support the agricultural sector.

# %% [markdown]
# ### Task 1.2.2:
#
# For the year 2021, generate choropleth maps of cereal yield for only the countries having a population greater than or equal to 331893745.

# %%
# identifying the countries in cereal with popluation >= 331893745 in 2021 using iso_a3

b = cereal_geo[cereal_geo['iso_a3'].isin(pop.loc[pop['2021']>= 331893745,'iso_a3'])]

# %%
# Create choropleth map to plot the identified countries in dataframe b

fig = px.choropleth(b,
                    geojson=b['Country Name'],
                    locations=b['iso_a3'],
                    color='2021',
                    hover_name='Country Name',
                    custom_data=[b['Country Name'],b['2021']],
                    title='Cereal Yield in 2021 for Countries with Population <= 300000000',
                    color_continuous_scale='ylorbr',
                    projection= 'natural earth')

fig.update_traces(hovertemplate='<b>%{customdata[0]}</b><br>Cereal yield: %{customdata[1]:.2f}<extra></extra>')

fig.update_geos(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="white", visible=False)

# Show the interactive map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7bacfd81-6ff9-43e6-b2ef-30347ee944a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bacfd81-6ff9-43e6-b2ef-30347ee944a3")) {                    Plotly.newPlot(                        "7bacfd81-6ff9-43e6-b2ef-30347ee944a3",                        [{"coloraxis":"coloraxis","customdata":[["United States",8268.0],["India",3478.8],["China",6320.8],["Eritrea",639.5]],"geo":"geo","geojson":["United States","India","China","Eritrea"],"hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003eCereal yield: %{customdata[1]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United States","India","China","Eritrea"],"locations":["USA","IND","CHN","ERI"],"name":"","z":[8268.0,3478.8,6320.8,639.5],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","s ...

# %% [markdown]
# For countries having a population greater than or equal to 331893745 in 2021, the plot illustrates:
#
# the United States exhibits a high cereal yield, reflecting its advanced agricultural sector.
#
# India has a moderate cereal yield, influenced by a combination of factors. The country has a diverse agricultural landscape, with variations in climate, soil types, and farming practices.
#
# Factors such as population pressure, small landholdings, and varying levels of technological adoption contribute to the moderate yield.
#
# China demonstrates a high cereal yield, reflecting its commitment to modernizing agriculture and increasing productivity.
#
# The Chinese government has implemented policies and invested in technology, infrastructure, and research to enhance agricultural efficiency.
#
# Eritrea has a lower cereal yield compared to the other countries. This may be attributed to challenges such as arid or semi-arid conditions, limited access to modern agricultural practices, and potential socio-economic factors impacting agricultural productivity.

# %% [markdown]
# ### Task 1.2.3:
#
# For the year 2021, generate choropleth maps of cereal yield for only the countries having a population between 10269022 and 1393409034.

# %%
# identifying the countries in cereal with popluation between 10269022 and 1393409034 in 2021 using iso_a3

c = cereal_geo[cereal_geo['iso_a3'].isin(pop.loc[pop['2021'].between(10000000,1000000000),'iso_a3'])]

# %%
# Create choropleth map to plot the identified countries in dataframe c

fig = px.choropleth(c,
                    geojson=c['Country Name'],
                    locations=c['iso_a3'],
                    color='2021',
                    hover_name='Country Name',
                    custom_data=[c['Country Name'],c['2021']],
                    title='Cereal Yield in 2021 for Countries with Population between 10000000 and 1000000000',
                    color_continuous_scale='ylorbr',
                    projection= 'natural earth')

fig.update_traces(hovertemplate='<b>%{customdata[0]}</b><br>Cereal yield: %{customdata[1]:.2f}<extra></extra>')

fig.update_geos(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="white", visible=False)

# Show the interactive map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f5ff6cc-24cd-4f7f-b843-ebc91fa82c7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f5ff6cc-24cd-4f7f-b843-ebc91fa82c7d")) {                    Plotly.newPlot(                        "6f5ff6cc-24cd-4f7f-b843-ebc91fa82c7d",                        [{"coloraxis":"coloraxis","customdata":[["Tanzania",1651.1],["Canada",3078.3],["United States",8268.0],["Kazakhstan",1049.0],["Uzbekistan",4735.9],["Indonesia",5351.3],["Argentina",5193.2],["Chile",6491.2],["Congo, Dem. Rep.",876.8],["Somalia",502.6],["Kenya",1487.6],["Sudan",566.8],["Chad",814.3],["Haiti",1153.8],["Dominican Republic",4784.8],["Russian Federation",2705.5],["South Africa",5124.7],["Mexico",3878.9],["Brazil",4478.7],["Bolivia",2502.1],["Peru",4686.5],["Colombia",5160.1],["Honduras",1900.2],["Guatemala",2218.0],["Venezuela, RB",3505.0],["France",7170.9],["Ecuador",4418.8],["Cuba",2403.9],["Zimbabwe",1545.2],["Senegal",1864.0],["Mali",1441.2],["Benin",1408.6],["Niger",349.6],["Nigeria",1636.6],["Cameroon",1669.4],["Ghana",2416.2],["Cote d'Ivoire",2294.0],["Guinea",1344.9],["Burkina Faso",1252.4],["Zambia",2525.0],["Malawi",2441.0],["Mozambique",1008.5],["Angola",1000.3],["Burundi",1481.5],["Madagascar",2675.3],["Tunisia",1453.8],["Algeria",1433.7],["Jordan",2290.1],["Iraq",2729.6],["Cambodia",3606.0],["Thailand",3092.6],["Myanmar",3612.2],["Vietnam",5947.1],["Korea, Dem. People's Rep.",3387.9],["Korea, Rep.",6809.4],["Bangladesh",4964.8],["Nepal",3208.4],["Pakistan",3564.9],["Afghanistan",2154.7],["Iran, Islamic Rep.",1635.2],["Syrian Arab Republic",820.4],["Sweden",5064.7],["Ukraine",5453.1],["Poland",4562.5],["Romania",5187.8],["Germany",6998.1],["Greece",4272.7],["Turkiye",2918.5],["Belgium",7906.2],["Netherlands",7872.3],["Portugal",5379.7],["Spain",4227.4],["Australia",2548.0],["Sri Lanka",4557.2],["Italy",5562.8],["United Kingdom",6966.8],["Azerbaijan",3297.4],["Philippines",3834.8],["Malaysia",3801.7],["Czechia",6113.0],["Eritrea",639.5],["Japan",6787.3],["Yemen, Rep.",791.8],["Saudi Arabia",5021.7],["Morocco",2328.2],["Egypt, Arab Rep.",7132.5],["Ethiopia",2787.9],["Uganda",2456.1],["Rwanda",1504.7],["South Sudan",844.6]],"geo":"geo","geojson":["Tanzania","Canada","United States","Kazakhstan","Uzbekistan","Indonesia","Argentina","Chile","Congo, Dem. Rep.","Somalia","Kenya","Sudan","Chad","Haiti","Dominican Republic","Russian Federation","South Africa","Mexico","Brazil","Bolivia","Peru","Colombia","Honduras","Guatemala","Venezuela, RB","France","Ecuador","Cuba","Zimbabwe","Senegal","Mali","Benin","Niger","Nigeria","Cameroon","Ghana","Cote d'Ivoire","Guinea","Burkina Faso","Zambia","Malawi","Mozambique","Angola","Burundi","Madagascar","Tunisia","Algeria","Jordan","Iraq","Cambodia","Thailand","Myanmar","Vietnam","Korea, Dem. People's Rep.","Korea, Rep.","Bangladesh","Nepal","Pakistan","Afghanistan","Iran, Islamic Rep.","Syrian Arab Republic","Sweden","Ukraine","Poland","Romania","Germany","Greece","Turkiye","Belgium","Netherlands","Portugal","Spain","Australia","Sri Lanka","Italy","United Kingdom","Azerbaijan","Philippines","Malaysia","Czechia","Eritrea","Japan","Yemen, Rep.","Saudi Arabia","Morocco","Egypt, Arab Rep.","Ethiopia","Uganda","Rwanda","South Sudan"],"hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003eCereal yield: %{customdata[1]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tanzania","Canada","United States","Kazakhstan","Uzbekistan","Indonesia","Argentina","Chile","Congo, Dem. Rep.","Somalia","Kenya","Sudan","Chad","Haiti","Dominican Republic","Russian Federation","South Africa","Mexico","Brazil","Bolivia","Peru","Colombia","Honduras","Guatemala","Venezuela, RB","France","Ecuador","Cuba","Zimbabwe","S ...

# %% [markdown]
# For countries having a population between 10269022 and 1393409034 in 2021, the plot shows that there is significant variability in cereal yield, ranging from a few hundred to several thousand kg/ha.
#
# Some countries, such as the United States, China, and several European nations, have relatively high cereal yields (e.g., above 5,000 kg/ha).
#
# Other countries, particularly in Africa and parts of Asia, exhibit lower cereal yields (e.g., below 2,000 kg/ha).
#
# Countries with higher cereal yields often invest heavily in agricultural research and technology. The United States, Netherlands, and France, for example, have advanced agricultural practices, modern machinery, and access to cutting-edge technologies that contribute to increased productivity.
#
# In some regions, traditional subsistence farming practices may prevail, focusing on meeting immediate food needs rather than maximizing yields.
#
# Niger is located in the Sahel region, which is susceptible to climate variability and extreme weather events. Erratic rainfall patterns and prolonged droughts can negatively impact crop production.

# %% [markdown]
# ### Task 1.2.4
#
# Plot (scatter or line plot) the percentage change in cereal yield from 2011 to 2021, for the country having the highest population in 2021. In this question, you must consider the cereal yield for each year between 2011 and 2021.

# %%
# identifying the country with highest populations from 2011 to 2021

high_pop = pop[pop['Country Name'].isin(cereal_geo['Country Name'])].nlargest(1, '2021')['Country Name'].iloc[0]

# %%
high_pop
# Out:
# 'China'

# %%
# creating a dataframe for the identified highest populated country from 2010 to 2021. 2010 is considered so that percentage change for 2011 from 2010 can be used.

cereal1 = cereal[cereal['Country Name'] == high_pop]
cereal1 = cereal1.loc[:, '2010':'2021']

# %%
# transposing the cereal dataframe to use it for line plot

cereal1 = cereal1.transpose()
cereal1.columns=['Cereal_yield']
cereal1
# Out:
#       Cereal_yield
# 2010        5526.1
# 2011        5709.4
# 2012        5827.1
# 2013        5894.1
# 2014        5893.2
# 2015        5985.7
# 2016        6017.6
# 2017        6111.3
# 2018        6125.4
# 2019        6265.9
# 2020        6314.2
# 2021        6320.8

# %%
# calculating the percentage change and storing it in a column 'change' in cereal1.

cereal1['change'] = cereal1.pct_change()
cereal1
# Out:
#       Cereal_yield    change
# 2010        5526.1       NaN
# 2011        5709.4  0.033170
# 2012        5827.1  0.020615
# 2013        5894.1  0.011498
# 2014        5893.2 -0.000153
# 2015        5985.7  0.015696
# 2016        6017.6  0.005329
# 2017        6111.3  0.015571
# 2018        6125.4  0.002307
# 2019        6265.9  0.022937
# 2020        6314.2  0.007708
# 2021        6320.8  0.001045

# %%
# remove the year 2010 from the cereal1 dataframe

cereal1 = cereal1.drop('2010', axis=0)
cereal1
# Out:
#       Cereal_yield    change
# 2011        5709.4  0.033170
# 2012        5827.1  0.020615
# 2013        5894.1  0.011498
# 2014        5893.2 -0.000153
# 2015        5985.7  0.015696
# 2016        6017.6  0.005329
# 2017        6111.3  0.015571
# 2018        6125.4  0.002307
# 2019        6265.9  0.022937
# 2020        6314.2  0.007708
# 2021        6320.8  0.001045

# %%
# plotting the line graph using the cereal1 dataframe for the percentage change in cereal yield from 2011 to 2021

fig = px.line(cereal1, x=cereal1.index, y='change',
              markers=True,
              color_discrete_sequence=['darkseagreen'],
              labels={'change': 'Percentage Change'},
              custom_data=['Cereal_yield', 'change'],
              title="Percentage Change in Cereal Yield (2011-2021)")

fig.update_layout(xaxis_title='Year', yaxis_title='Percentage Change',
                  title_x=0.5, hovermode='x unified')

fig.update_traces(hovertemplate='<b>Year</b>: %{x}<br>'
                                '<b>Cereal Yield</b>: %{customdata[0]:,.2f}<br>'
                                '<b>Change</b>: %{customdata[1]:,.6f}',
                 line=dict(width=2.5),
                 marker=dict(size=8,color='green'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28438479-28b4-4592-a784-be6e96b8ed98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28438479-28b4-4592-a784-be6e96b8ed98")) {                    Plotly.newPlot(                        "28438479-28b4-4592-a784-be6e96b8ed98",                        [{"customdata":[[5709.4,0.03316986663288746],[5827.1,0.020615125932672562],[5894.1,0.011498000720770118],[5893.2,-0.00015269506794934884],[5985.7,0.015696056471865782],[6017.6,0.0053293683278481385],[6111.3,0.01557099175751131],[6125.4,0.0023072014137743846],[6265.9,0.022937277565546754],[6314.2,0.007708389856205811],[6320.8,0.001045263057869672]],"hovertemplate":"\u003cb\u003eYear\u003c\u002fb\u003e: %{x}\u003cbr\u003e\u003cb\u003eCereal Yield\u003c\u002fb\u003e: %{customdata[0]:,.2f}\u003cbr\u003e\u003cb\u003eChange\u003c\u002fb\u003e: %{customdata[1]:,.6f}","legendgroup":"","line":{"color":"darkseagreen","dash":"solid","width":2.5},"marker":{"symbol":"circle","color":"green","size":8},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.03316986663288746,0.020615125932672562,0.011498000720770118,-0.00015269506794934884,0.015696056471865782,0.0053293683278481385,0.01557099175751131,0.0023072014137743846,0.022937277565546754,0.007708389856205811,0.001045263057869672],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %% [markdown]
# The cereal yield has generally shown a positive trend over the years, with an increasing percentage change.
#
# In 2011, the cereal yield was 5709.4 kg/ha, and it experienced a steady upward trend over the subsequent years.
#
# The highest percentage change occurred in 2019, with a substantial increase of 2.29%.
#
# Despite a slight dip in 2014, the overall trend remained positive, indicating a consistent improvement in cereal yield.
#
# In 2021, the cereal yield reached 6320.8 kg/ha, reflecting a continuous positive trajectory.
#
# The country has made significant progress in improving cereal yields over the analyzed period, with a focus on agricultural productivity and potentially adopting more efficient farming practices or technologies.
#
# The positive percentage changes signify a positive trend in cereal production, contributing to food security and agricultural sustainability.

# %% [markdown]
# ### Task 1.2.5:
#
# Present a scatter plot between the mean population of each country and the mean cereal yield from the year 2011 until 2021.

# %%
# creating cereal2 dataframe whose countries are available in loc dataframe and inserting a column 'mean' calculating mean ceral yield of countries from 2011 to 2021.

cereal2 = cereal[cereal['iso_a3'].isin(loc['iso_a3'])]
cereal2 = cereal2.set_index(['Country Name'])
cereal2 = cereal2.iloc[:,51:]

cereal2['cereal_mean'] = cereal2.mean(axis=1)
cereal2 = cereal2.iloc[:,11:]
cereal2
# Out:
#                        cereal_mean
# Country Name
# Afghanistan            2027.327273
# Angola                  860.363636
# Albania                4919.336364
# United Arab Emirates  25778.954545
# Argentina              4938.290909
# ...                            ...
# Vanuatu                 604.836364
# Yemen, Rep.             857.145455
# South Africa           4409.563636
# Zambia                 2573.190909
# Zimbabwe                879.545455
#
# [169 rows x 1 columns]

# %%
# checking for null values in cereal2

cereal2.isna().sum()
# Out:
# cereal_mean    0
# dtype: int64

# %%
# creating pop1 dataframe whose countries are available in loc dataframe and inserting a column 'mean' calculating mean population of countries from 2011 to 2021.

pop1 = pop[pop['iso_a3'].isin(loc['iso_a3'])]
pop1 = pop1.set_index(['Country Name'])
pop1 = pop1.iloc[:,52:]

pop1['pop_mean'] = pop1.mean(axis=1)
pop1 = pop1.iloc[:,11:]
pop1
# Out:
#                           pop_mean
# Country Name
# Afghanistan           3.518085e+07
# Angola                2.893316e+07
# Albania               2.871830e+06
# United Arab Emirates  9.444956e+06
# Argentina             4.356846e+07
# ...                            ...
# Vanuatu               2.783465e+05
# Yemen, Rep.           2.715723e+07
# South Africa          5.612482e+07
# Zambia                1.640259e+07
# Zimbabwe              1.400614e+07
#
# [169 rows x 1 columns]

# %%
# checking for null values in pop1

pop1.isna().sum()
# Out:
# pop_mean    0
# dtype: int64

# %%
# creating a dataframe with country name, cereal mean and population mean by merging cereal2 and pop1

mean_df = cereal2.join(pop1)
mean_df.reset_index(inplace=True)
mean_df
# Out:
#              Country Name   cereal_mean      pop_mean
# 0             Afghanistan   2027.327273  3.518085e+07
# 1                  Angola    860.363636  2.893316e+07
# 2                 Albania   4919.336364  2.871830e+06
# 3    United Arab Emirates  25778.954545  9.444956e+06
# 4               Argentina   4938.290909  4.356846e+07
# ..                    ...           ...           ...
# 164               Vanuatu    604.836364  2.783465e+05
# 165           Yemen, Rep.    857.145455  2.715723e+07
# 166          South Africa   4409.563636  5.612482e+07
# 167                Zambia   2573.190909  1.640259e+07
# 168              Zimbabwe    879.545455  1.400614e+07
#
# [169 rows x 3 columns]

# %%
# checking for null values in merged dataframe

mean_df.isna().sum()
# Out:
# Country Name    0
# cereal_mean     0
# pop_mean        0
# dtype: int64

# %%
# plotting the mean population and mean cereal yield of countries from 2011 to 2021

correlation = mean_df[['cereal_mean', 'pop_mean']].corr().iloc[0, 1]

fig = px.scatter(mean_df, x='cereal_mean', y='pop_mean', color='Country Name', custom_data=['Country Name', 'cereal_mean', 'pop_mean'])

fig.update_traces(hovertemplate='Country: %{customdata[0]}<br>Cereal yield Mean: %{customdata[1]:.2f}<br>Population Mean: %{customdata[2]:,.0f}')
fig.update_layout(title="Population Vs Cereal yield mean of countries from 2011 to 2021",title_x=0.5, annotations=[{'x': 0.5,'y': 1.05,'showarrow': False,'text': f'Correlation: {correlation:.2f}','xref': 'paper','yref': 'paper'}])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ce5969b0-67e4-4022-9cf3-cd33ecdec59c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce5969b0-67e4-4022-9cf3-cd33ecdec59c")) {                    Plotly.newPlot(                        "ce5969b0-67e4-4022-9cf3-cd33ecdec59c",                        [{"customdata":[["Afghanistan",2027.3272727272729,35180852.27272727]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Afghanistan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2027.3272727272729],"xaxis":"x","y":[35180852.27272727],"yaxis":"y","type":"scatter"},{"customdata":[["Angola",860.3636363636364,28933158.181818184]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Angola","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[860.3636363636364],"xaxis":"x","y":[28933158.181818184],"yaxis":"y","type":"scatter"},{"customdata":[["Albania",4919.336363636363,2871830.4545454546]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Albania","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[4919.336363636363],"xaxis":"x","y":[2871830.4545454546],"yaxis":"y","type":"scatter"},{"customdata":[["United Arab Emirates",25778.95454545454,9444956.181818182]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"United Arab Emirates","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"United Arab Emirates","orientation":"v","showlegend":true,"x":[25778.95454545454],"xaxis":"x","y":[9444956.181818182],"yaxis":"y","type":"scatter"},{"customdata":[["Argentina",4938.29090909091,43568460.45454545]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Argentina","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[4938.29090909091],"xaxis":"x","y":[43568460.45454545],"yaxis":"y","type":"scatter"},{"customdata":[["Armenia",2590.0272727272722,2928917.909090909]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Armenia","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[2590.0272727272722],"xaxis":"x","y":[2928917.909090909],"yaxis":"y","type":"scatter"},{"customdata":[["Australia",2107.572727272727,24187911.09090909]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Australia","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[2107.572727272727],"xaxis":"x","y":[24187911.09090909],"yaxis":"y","type":"scatter"},{"customdata":[["Austria",6659.7363636363625,8692575.454545455]],"hovertemplate":"Country: %{customdata[0]}\u003cbr\u003eCereal yield Mean: %{customdata[1]:.2f}\u003cbr\u003ePopulation Mean: %{customdata[2]:,.0f}","legendgroup":"Austria","marker":{"color":"#B6E8 ...

# %% [markdown]
# The above scatter plot of Population Vs Cereal yield mean of countries from 2011 to 2021 illustrates:
#
# both India and China, with populations exceeding 1 billion, exhibit mean cereal yields below 10,000 kg/ha.
#
# This suggests that despite their large populations, the average productivity in cereal cultivation (yield per hectare) is relatively low.
#
# Larger-population countries might have more pressure on arable land and resources, leading to suboptimal agricultural practices and lower yields.
#
# The United Arab Emirates (UAE), with a population of less than 50 million, stands out with the highest mean cereal yield, surpassing 25,000 kg/ha.
#
# This indicates that the UAE has a more efficient and productive cereal cultivation system, leading to higher yields despite a smaller population.
#
# Smaller-population countries may have more flexibility and resources to implement advanced agricultural technologies and practices, resulting in higher yields.
#
# A general trend is observed where the majority of countries with populations below 50 million tend to have mean cereal yields below 7,000 kg/ha.
#
# This suggests that, on average, smaller populations are associated with lower cereal yields.
#
# While there is a slight tendency for countries with higher populations to have slightly higher mean cereal yields, the correlation(0.06) is weak, suggesting that population size alone is not a strong predictor of cereal yield.
#
# Overall, the data on cereal yield and population can provide valuable insights for policymakers, researchers, and organizations working in agriculture and food security. Understanding the factors influencing these trends can lead to more informed decision-making and sustainable practices in the agricultural sector.
